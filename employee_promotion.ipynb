# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data = {
    "projects_completed":[1,2,3,4,2,5],
    "Attendance":[80,88,90,95,85,97],
    "passed":[0,0,1,1,0,1]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    projects_completed  Attendance  passed
# 0                   1          80       0
# 1                   2          88       0
# 2                   3          90       1
# 3                   4          95       1
# 4                   2          85       0
# 5                   5          97       1

# %%
x = df[['projects_completed','Attendance']]
y = df['passed']

# %%
x_train , x_test , y_train , y_test = train_test_split(x ,y ,test_size=0.2,random_state=42)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("accuracy score:",accuracy_score(y_test,y_pred))
print("confusion matrix:\n",confusion_matrix(y_test,y_pred))
# Out:
# accuracy score: 0.5
# confusion matrix:
#  [[1 1]
#  [0 0]]

# %%
new_project = [[6,90]]
predicted = model.predict(new_project)

print("passed [1] or Fail [0]:",predicted[0])
# Out:
# passed [1] or Fail [0]: 1
# d:\Machine Learning\machine\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df['projects_completed'],df['passed'],s=80)
plt.xlabel("Projects completed")
plt.ylabel("Passed (0 = No, 1 = Yes)")
plt.title("Logistic Regression Classification data")
plt.grid(True)
plt.show()
