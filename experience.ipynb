# %%
import matplotlib.pyplot as plt 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error,r2_score

# %%
data = {
    'experience':[1,2,3,4,5,6],
    'salary':[3.2,4.0,4.7,5.5,6.3,7.1]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    experience  salary
# 0           1     3.2
# 1           2     4.0
# 2           3     4.7
# 3           4     5.5
# 4           5     6.3
# 5           6     7.1

# %%
x = df[['experience']]
y = df['salary']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2,random_state=42 )

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =  model.predict(x_test)

# %%
print("Root Mean Squared Error:",root_mean_squared_error(y_test,y_pred))
print("R^2 score:",r2_score(y_test,y_pred))
# Out:
# Root Mean Squared Error: 0.09999999999999876
# R^2 score: 0.9375000000000016

# %%
plt.scatter(x,y,color='red',label='Actual data')
plt.plot(x,model.predict(x),color='yellow',label='Regression Line')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Experience vs Salary')
plt.legend()
plt.show()

# %%
exp = 4.5
new_data = pd.DataFrame({'experience':[exp]})
predicted_salary = model.predict(new_data)
print(f"predicted Salary  for {exp} salary={predicted_salary[0]:2f}")
# Out:
# predicted Salary  for 4.5 salary=5.900000
