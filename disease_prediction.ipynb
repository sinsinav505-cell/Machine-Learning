# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
data ={
    'fever':[98,99.5,100.5,101,102,98.5],
    'cough_level':[1,2,3,4,5,1],
    'passed':[0,0,1,1,1,0]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    fever  cough_level  passed
# 0   98.0            1       0
# 1   99.5            2       0
# 2  100.5            3       1
# 3  101.0            4       1
# 4  102.0            5       1
# 5   98.5            1       0

# %%
x = df[['fever','cough_level']]
y = df['passed']

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y, test_size=0.2,random_state=42)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy score:",accuracy_score(y_test,y_pred))
print("Confusion matrix:\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy score: 0.5
# Confusion matrix:
#  [[1 1]
#  [0 0]]

# %%
new_value = [[97,1]]
prediiction = model.predict(new_value)
print("sick if yes[1] ,no[0]:",prediiction[0])
# Out:
# sick if yes[1] ,no[0]: 0
# d:\Machine Learning\machine\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df['fever'],df['passed'],s=80)
plt.xlabel("fever")
plt.ylabel("passed")
plt.grid(True)
plt.show()
